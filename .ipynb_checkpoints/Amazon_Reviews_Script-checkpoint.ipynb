# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import seaborn as sns
from scipy import stats
import json

# %%
music_list=[]
filepath_music = os.path.join("Digital_Music_5.json")
with open(filepath_music) as jsonfile:
    for line in jsonfile: 
        music_json=json.loads(line)
        music_list.append(music_json)
        
music_df = pd.DataFrame(music_list)
music_df
# Out:
#            reviewerID        asin                 reviewerName helpful  \
# 0      A3EBHHCZO6V2A4  5555991584         Amaranth "music fan"  [3, 3]
# 1       AZPWAXJG9OJXV  5555991584                    bethtexas  [0, 0]
# 2      A38IRL0X2T4DPF  5555991584                  bob turnley  [2, 2]
# 3      A22IK3I6U76GX0  5555991584                        Calle  [1, 1]
# 4      A1AISPOIIHTHXX  5555991584                  Cloud "..."  [1, 1]
# ...               ...         ...                          ...     ...
# 64701  A1PQ1PESSO8CMO  B00KILDVEI             Ginger Christmas  [0, 0]
# 64702  A120RH58WVY4W6  B00KILDVEI  Kelly Dunwell "avid reader"  [0, 0]
# 64703  A19VJ2IQLO50G0  B00KILDVEI                      melinda  [0, 1]
# 64704   AUDSM2CTLLW1Q  B00KILDVEI           Patrick L. Randall  [0, 0]
# 64705  A1GN8UJIZLCA59  B00KILDVEI                     P Magnum  [1, 2]
#
#                                               reviewText  overall  \
# 0      It's hard to believe "Memory of Trees" came ou...      5.0
# 1      A clasically-styled and introverted album, Mem...      5.0
# 2      I never thought Enya would reach the sublime h...      5.0
# 3      This is the third review of an irish album I w...      5.0
# 4      Enya, despite being a successful recording art...      4.0
# ...                                                  ...      ...
# 64701  I like the reggae sound a lot in this song. I ...      4.0
# 64702  I first heard this on Sirius and had to have i...      5.0
# 64703  I absolutely love this song, it downloaded fin...      5.0
# 64704  Reggae, island beats aren't really my cup of t...      3.0
# 64705  Magic! is a Canadian band that incorporates re...      1.0
#
#                             summary  unixReviewTime   reviewTime
# 0           Enya's last great album      1158019200  09 12, 2006
# 1          Enya at her most elegant       991526400   06 3, 2001
# 2                   The best so far      1058140800  07 14, 2003
# 3      Ireland produces good music.       957312000   05 3, 2000
# 4            4.5; music to dream to      1200528000  01 17, 2008
# ...                             ...             ...          ...
# 64701                     Cool song      1403568000  06 24, 2014
# 64702                    Great Song      1404864000   07 9, 2014
# 64703                    Five Stars      1405209600  07 13, 2014
# 64704             Well-crafted song      1404864000   07 9, 2014
# 64705                Souless Reggae      1405641600  07 18, 2014
#
# [64706 rows x 9 columns]

# %%
meta_music=[]
i=0
filepath_metamusic = os.path.join("meta_Digital_Music.json")
with open(filepath_metamusic) as jsonfile:
    for line in jsonfile: 
        i+=1
        try: 
            music_json=json.loads(line)
            meta_music.append(music_json)
        except: 
            print(i)
            continue       
            
metamusic_df = pd.DataFrame(meta_music)
metamusic_df
# Out:
#       category tech1                                        description fit  \
# 0           []                                                       []
# 1           []                                                       []
# 2           []                                                       []
# 3           []                                                       []
# 4           []        [1. Losing Game 2. I Can't Wait 3. Didn't He S...
# ...        ...   ...                                                ...  ..
# 74342       []        [1. "Free At Last" Southside 1:21 2. "Never Go...
# 74343       []                                                       []
# 74344       []                                                       []
# 74345       []                                                       []
# 74346       []        [album 2016: 01.Autogram 02.Dobrotvorne svrhe ...
#
#                                                    title  \
# 0                           Master Collection Volume One
# 1                      Hymns Collection: Hymns 1 &amp; 2
# 2                            Early Works - Don Francisco
# 3                          So You Wanna Go Back to Egypt
# 4                              Early Works - Dallas Holm
# ...                                                  ...
# 74342                         FUTURE PRESENTS: 56 NIGHTS
# 74343  Tori Amos - Little Earthquakes? - Lp Vinyl Record
# 74344  EXO - EX'ACT 3rd Album [Korean Lucky One Versi...
# 74345                      Vanilla Fudge (Korea Edition)
# 74346  CD Svetlana Ceca Raznatovic New Album 2016 Aut...
#
#                                                 also_buy tech2  \
# 0      [B000002UEN, B000008LD5, B01J804JKE, 747403435...
# 1                               [5558154950, B00014K5V4]
# 2      [B00004RC05, B003H8F4NA, B003ZFVHPO, B003JMP1Z...
# 3      [B0000275QQ, 0001393774, 0001388312, B0016CP2G...
# 4      [B0002N4JP2, 0760131694, B00002EQ79, B00150K8J...
# ...                                                  ...   ...
# 74342                                                 []
# 74343                                                 []
# 74344  [B07HSM242F, B00VMJ1MMS, B077ZYR799, B00YSOAJG...
# 74345                                                 []
# 74346                                       [8652700087]
#
#                           brand feature                        rank  \
# 0           John Michael Talbot      []     58,291 in CDs & Vinyl (
# 1        Second Chapter of Acts      []     93,164 in CDs & Vinyl (
# 2                 Don Francisco      []    875,825 in CDs & Vinyl (
# 3                   Keith Green      []    203,263 in CDs & Vinyl (
# 4                   Dallas Holm      []    399,269 in CDs & Vinyl (
# ...                         ...     ...                         ...
# 74342                    FUTURE      []    695,581 in CDs & Vinyl (
# 74343                 Tori Amos      []  1,577,399 in CDs & Vinyl (
# 74344                       EXO      []    130,165 in CDs & Vinyl (
# 74345                                []                          []
# 74346  Svetlana Ceca Raznatovic      []    159,741 in CDs & Vinyl (
#
#                                                also_view  \
# 0      [B000002UEN, B000008LD5, 7474034352, B000008LD...
# 1      [B000008KJ3, B000008KJ0, 5558154950, B000UN8KZ...
# 2      [B003H8F4NA, B003ZFVHPO, B003JMP1ZK, B00004RC0...
# 3      [B00000I7JO, B0016CP2GS, 0001393774, B0000275Q...
# 4      [B0002N4JP2, 0760131694, B00150K8JC, B003MTXNV...
# ...                                                  ...
# 74342                                                 []
# 74343                                                 []
# 74344  [B07HSM242F, B01KNSVGKQ, B077ZYR799, B075D9V4W...
# 74345  [B000002IAK, B00019PDWU, B00000GX0F, B00000GX0...
# 74346                                                 []
#
#                                                 main_cat similar_item date  \
# 0      <img src="https://images-na.ssl-images-amazon....
# 1      <img src="https://images-na.ssl-images-amazon....
# 2      <img src="https://images-na.ssl-images-amazon....
# 3      <img src="https://images-na.ssl-images-amazon....
# 4      <img src="https://images-na.ssl-images-amazon....
# ...                                                  ...          ...  ...
# 74342  <img src="https://images-na.ssl-images-amazon....
# 74343  <img src="https://images-na.ssl-images-amazon....
# 74344  <img src="https://images-na.ssl-images-amazon....
# 74345  <img src="https://images-na.ssl-images-amazon....
# 74346  <img src="https://images-na.ssl-images-amazon....
#
#         price        asin                                           imageURL  \
# 0      $18.99  0001377647                                                 []
# 1              0001529145                                                 []
# 2              0001527134                                                 []
# 3      $13.01  0001388703                                                 []
# 4              0001526146                                                 []
# ...       ...         ...                                                ...
# 74342          B01HH7D5KU  [https://images-na.ssl-images-amazon.com/image...
# 74343          B01HHGQXI2  [https://images-na.ssl-images-amazon.com/image...
# 74344          B01HHRIKKK  [https://images-na.ssl-images-amazon.com/image...
# 74345          B01HI2B3G2                                                 []
# 74346   $9.39  B01HIT3KZC  [https://images-na.ssl-images-amazon.com/image...
#
#                                          imageURLHighRes  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 74342  [https://images-na.ssl-images-amazon.com/image...
# 74343  [https://images-na.ssl-images-amazon.com/image...
# 74344  [https://images-na.ssl-images-amazon.com/image...
# 74345                                                 []
# 74346  [https://images-na.ssl-images-amazon.com/image...
#
#                                                  details
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 74342           {'Label:': 'FBG', 'ASIN:': 'B01HH7D5KU'}
# 74343  {'Original Release Date:': '2015', 'Number of ...
# 74344                            {'ASIN:': 'B01HHRIKKK'}
# 74345                            {'ASIN:': 'B01HI2B3G2'}
# 74346   {'Number of Discs:': '1', 'ASIN:': 'B01HIT3KZC'}
#
# [74347 rows x 19 columns]

# %%
cd_list=[]
filepath_cd = os.path.join("CDs_and_Vinyl_5.json")
with open(filepath_cd) as jsonfile:
    for line in jsonfile: 
        cd_json=json.loads(line)
        cd_list.append(cd_json)
        
cd_df = pd.DataFrame(cd_list)
cd_df
# Out:
#              reviewerID        asin           reviewerName  verified  \
# 0        A1H1DL4K669VQ9  0001393774        Judith Paladino      True
# 1        A3V5XBBT7OZG5G  0001393774                 gflady      True
# 2        A3SNL7UJY7GWBI  0001393774       Lady Leatherneck      True
# 3        A3478QRKQDOPQ2  0001393774                  jacki      True
# 4        A23M5VTSN2C3H1  0001393774                Caliope      True
# ...                 ...         ...                    ...       ...
# 1443750  A30ZM19J0CNAGJ  B01HJDG28E  Reggie: a music lover      True
# 1443751   APXJ8QC63EG38  B01HJG3VZI         Steven Schubak      True
# 1443752   A5HIGHKQPINEO  B01HJG3VZI                   Oman      True
# 1443753  A1B26TNQEWHQ4K  B01HJG3VZI      David W. Barsness      True
# 1443754  A1KCWOF28NPM3M  B01HJG3VZI               Peter G.      True
#
#                                                 reviewText  overall  \
# 0                                 Love it!!  Great seller!      5.0
# 1        One of my very favourite albums from one of my...      5.0
# 2        THank you Jesus Lord God, that brother Green's...      5.0
# 3        I recall loving his other albums and maybe thi...      5.0
# 4        Keith Green was a pioneer in the field of Chri...      5.0
# ...                                                    ...      ...
# 1443750  Night Hawk is ten outstanding new recordings o...      5.0
# 1443751                                                 ok      3.0
# 1443752  Great music great sound love the music lots of...      5.0
# 1443753                      Really good fun quality stuff      5.0
# 1443754  Great 5 LP by The Guess Who, love all these al...      5.0
#
#           reviewTime                                            summary  \
# 0        04 29, 2016                                         Five Stars
# 1        02 23, 2016  One of my very favourite albums from one of my...
# 2        02 11, 2016                                         Five Stars
# 3        11 28, 2015  forgot but I figured on some of these artists ...
# 4        12 16, 2014                and I have loved every album he did
# ...              ...                                                ...
# 1443750  12 31, 2016  My favorite cut is the cover of "(Ghost) Rider...
# 1443751  07 25, 2018                                        Three Stars
# 1443752  07 17, 2018               The sound quality and number of hits
# 1443753  06 23, 2018                                               5fer
# 1443754   11 4, 2017                                  Guess Who 5 Pack!
#
#          unixReviewTime                     style vote image
# 0            1461888000                       NaN  NaN   NaN
# 1            1456185600                       NaN  NaN   NaN
# 2            1455148800                       NaN  NaN   NaN
# 3            1448668800                       NaN  NaN   NaN
# 4            1418688000                       NaN  NaN   NaN
# ...                 ...                       ...  ...   ...
# 1443750      1483142400  {'Format:': ' Audio CD'}  NaN   NaN
# 1443751      1532476800  {'Format:': ' Audio CD'}  NaN   NaN
# 1443752      1531785600  {'Format:': ' Audio CD'}  NaN   NaN
# 1443753      1529712000  {'Format:': ' Audio CD'}  NaN   NaN
# 1443754      1509753600  {'Format:': ' Audio CD'}  NaN   NaN
#
# [1443755 rows x 12 columns]

# %%
meta_cd=[]
i=0
filepath_metacd = os.path.join("meta_CDs_and_Vinyl.json")
with open(filepath_metacd) as jsonfile:
    for line in jsonfile: 
        i+=1
        try: 
            cd_json=json.loads(line)
            meta_cd.append(cd_json)
        except: 
            print(i)
            continue       
            
metacd_df = pd.DataFrame(meta_cd)
metacd_df
# Out:
#                                             category tech1  \
# 0                           [CDs & Vinyl, Christian]
# 1       [CDs & Vinyl, Christian, Pop & Contemporary]
# 2               [CDs & Vinyl, Christian, Children's]
# 3               [CDs & Vinyl, Christian, Children's]
# 4               [CDs & Vinyl, Christian, Children's]
# ...                                              ...   ...
# 516909                            [CDs & Vinyl, Pop]
# 516910                        [CDs & Vinyl, Country]
# 516911                 [CDs & Vinyl, Pop, Vocal Pop]
# 516912                            [CDs & Vinyl, Pop]
# 516913                            [CDs & Vinyl, Pop]
#
#                                               description fit  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3       [1) To God Be The Glory2) This Is My Fathers W...
# 4       [Joy To The World 2 The First Noel 3 Hark! The...
# ...                                                   ...  ..
# 516909                                                 []
# 516910                 [CHARLIE DANIELS - NIGHTHAWK - CD]
# 516911  [Five CD set containing a quintet of albums by...
# 516912  [2016 five CD set containing a quintet of orig...
# 516913  [2016 album by US-born Australian singer-songw...
#
#                                        title  \
# 0                     Songs for the Shepherd
# 1            Lift Him Up With Ron Kenoly VHS
# 2                                 I Love You
# 3       Hymns: 16 Classic Hymns for Children
# 4                           Christmas Carols
# ...                                      ...
# 516909                              Furnaces
# 516910                            Night Hawk
# 516911               Original Album Classics
# 516912               Original Album Classics
# 516913                             Americana
#
#                                                  also_buy tech2  \
# 0       [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...
# 1                    [6303908845, 6303646611, B000008GO1]
# 2                                                      []
# 3       [B00000DPLJ, B000008UPG, B00BQH9RKA, B00KYVHGR...
# 4                                [B0010WAC50, B00000DPLJ]
# ...                                                   ...   ...
# 516909  [B07CBLRXNP, B01MYB68L4, B07BZBD1TY, B01MY7Z66...
# 516910  [0718074963, B0012GMV5S, B00I89Y2SQ, B07H5VY3L...
# 516911  [B00A7F17Z0, B00975L6O8, B00NMUCLBQ, B000002VE...
# 516912  [B06Y1L22WT, B017CJL0BO, B005JS7VTQ, B01FJ2UKD...
# 516913                                                 []
#
#                        brand feature                        rank  \
# 0                Keith Green      []    123,896 in CDs & Vinyl (
# 1                                 []    284,935 in Movies & TV (
# 2            Integrity Music      []  1,138,833 in CDs & Vinyl (
# 3                    Sue Gay      []    271,064 in CDs & Vinyl (
# 4             Cedarmont Kids      []    409,293 in CDs & Vinyl (
# ...                      ...     ...                         ...
# 516909           Ed Harcourt      []    251,328 in CDs & Vinyl (
# 516910  Charlie Daniels Band      []     68,288 in CDs & Vinyl (
# 516911        Dionne Warwick      []     69,386 in CDs & Vinyl (
# 516912         The Guess Who      []      1,795 in CDs & Vinyl (
# 516913                DIESEL      []  1,759,107 in CDs & Vinyl (
#
#                                                 also_view  \
# 0       [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 1                                            [B00000DUDE]
# 2                                                      []
# 3       [B00000DPLL, 0843113006, B00BQH9RKA, B000008UP...
# 4       [B00000DPKG, B0010WAC50, B00000DPKH, B00FSZPM8...
# ...                                                   ...
# 516909  [B07JBYSQ63, B00B8ZOZ84, B0048IDRJQ, B00HVKMYY...
# 516910  [B07H5VY3LK, B00FLV06V6, B00I89Y2SQ, B01JU6OYK...
# 516911  [B00A7F17Z0, B0000032WJ, B00000IFVX, B00004SW9...
# 516912  [B000CNE11O, B00000I0QI, B0042OZDP2, B0015XAT4...
# 516913                                                 []
#
#                                                  main_cat similar_item date  \
# 0       <img src="https://images-na.ssl-images-amazon....
# 1                                             Movies & TV
# 2       <img src="https://images-na.ssl-images-amazon....
# 3       <img src="https://images-na.ssl-images-amazon....
# 4       <img src="https://images-na.ssl-images-amazon....
# ...                                                   ...          ...  ...
# 516909  <img src="https://images-na.ssl-images-amazon....
# 516910  <img src="https://images-na.ssl-images-amazon....
# 516911  <img src="https://images-na.ssl-images-amazon....
# 516912  <img src="https://images-na.ssl-images-amazon....
# 516913  <img src="https://images-na.ssl-images-amazon....
#
#                                                     price        asin  \
# 0                                                          0001393774
# 1                                                          0001501348
# 2                                                          0001515209
# 3       .a-section.a-spacing-mini{margin-bottom:6px!im...  0005072298
# 4                                                          0005121515
# ...                                                   ...         ...
# 516909                                              $9.79  B01HJ7FPAG
# 516910                                              $8.00  B01HJDG28E
# 516911                                             $14.56  B01HJG3UQI
# 516912                                             $17.28  B01HJG3VZI
# 516913                                             $20.04  B01HJHLNIY
#
#                                                  imageURL  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 516909  [https://images-na.ssl-images-amazon.com/image...
# 516910  [https://images-na.ssl-images-amazon.com/image...
# 516911  [https://images-na.ssl-images-amazon.com/image...
# 516912  [https://images-na.ssl-images-amazon.com/image...
# 516913  [https://images-na.ssl-images-amazon.com/image...
#
#                                           imageURLHighRes  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 516909  [https://images-na.ssl-images-amazon.com/image...
# 516910  [https://images-na.ssl-images-amazon.com/image...
# 516911  [https://images-na.ssl-images-amazon.com/image...
# 516912  [https://images-na.ssl-images-amazon.com/image...
# 516913  [https://images-na.ssl-images-amazon.com/image...
#
#                                                   details
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 516909  {'Audio CD': '(August 26, 2016)', 'Number of D...
# 516910  {'Audio CD': '(August 26, 2016)', 'Original Re...
# 516911  {'Audio CD': '(September 9, 2016)', 'Original ...
# 516912  {'Audio CD': '(September 9, 2016)', 'Original ...
# 516913  {'Audio CD': '(July 1, 2016)', 'Number of Disc...
#
# [516914 rows x 19 columns]

# %%
merging_dig_df = pd.merge(metamusic_df, music_df, on="asin", how="outer")
merging_dig_df = merging_dig_df.dropna(subset=['overall'])
pd.options.display.max_columns = None
merging_dig_df
# Out:
#        category tech1                  description  fit      title  \
# 908          []        [CD > POPULAR MUSIC > ROCK]       Mezzanine
# 909          []        [CD > POPULAR MUSIC > ROCK]       Mezzanine
# 910          []        [CD > POPULAR MUSIC > ROCK]       Mezzanine
# 911          []        [CD > POPULAR MUSIC > ROCK]       Mezzanine
# 912          []        [CD > POPULAR MUSIC > ROCK]       Mezzanine
# ...         ...   ...                          ...  ...        ...
# 139046      NaN   NaN                          NaN  NaN        NaN
# 139047      NaN   NaN                          NaN  NaN        NaN
# 139048      NaN   NaN                          NaN  NaN        NaN
# 139049      NaN   NaN                          NaN  NaN        NaN
# 139050      NaN   NaN                          NaN  NaN        NaN
#
#                                                  also_buy tech2  \
# 908     [B000000WHX, B000001FI7, B000000W6X, B00007KK7...
# 909     [B000000WHX, B000001FI7, B000000W6X, B00007KK7...
# 910     [B000000WHX, B000001FI7, B000000W6X, B00007KK7...
# 911     [B000000WHX, B000001FI7, B000000W6X, B00007KK7...
# 912     [B000000WHX, B000001FI7, B000000W6X, B00007KK7...
# ...                                                   ...   ...
# 139046                                                NaN   NaN
# 139047                                                NaN   NaN
# 139048                                                NaN   NaN
# 139049                                                NaN   NaN
# 139050                                                NaN   NaN
#
#                  brand feature                     rank  \
# 908     Massive Attack      []  14,388 in CDs & Vinyl (
# 909     Massive Attack      []  14,388 in CDs & Vinyl (
# 910     Massive Attack      []  14,388 in CDs & Vinyl (
# 911     Massive Attack      []  14,388 in CDs & Vinyl (
# 912     Massive Attack      []  14,388 in CDs & Vinyl (
# ...                ...     ...                      ...
# 139046             NaN     NaN                      NaN
# 139047             NaN     NaN                      NaN
# 139048             NaN     NaN                      NaN
# 139049             NaN     NaN                      NaN
# 139050             NaN     NaN                      NaN
#
#                                                 also_view  \
# 908     [B00004WNFZ, B01LY6G5LY, B07GVZMKCL, B01L388UB...
# 909     [B00004WNFZ, B01LY6G5LY, B07GVZMKCL, B01L388UB...
# 910     [B00004WNFZ, B01LY6G5LY, B07GVZMKCL, B01L388UB...
# 911     [B00004WNFZ, B01LY6G5LY, B07GVZMKCL, B01L388UB...
# 912     [B00004WNFZ, B01LY6G5LY, B07GVZMKCL, B01L388UB...
# ...                                                   ...
# 139046                                                NaN
# 139047                                                NaN
# 139048                                                NaN
# 139049                                                NaN
# 139050                                                NaN
#
#                                                  main_cat similar_item date  \
# 908     <img src="https://images-na.ssl-images-amazon....
# 909     <img src="https://images-na.ssl-images-amazon....
# 910     <img src="https://images-na.ssl-images-amazon....
# 911     <img src="https://images-na.ssl-images-amazon....
# 912     <img src="https://images-na.ssl-images-amazon....
# ...                                                   ...          ...  ...
# 139046                                                NaN          NaN  NaN
# 139047                                                NaN          NaN  NaN
# 139048                                                NaN          NaN  NaN
# 139049                                                NaN          NaN  NaN
# 139050                                                NaN          NaN  NaN
#
#          price        asin imageURL imageURLHighRes  \
# 908     $11.49  B000006045       []              []
# 909     $11.49  B000006045       []              []
# 910     $11.49  B000006045       []              []
# 911     $11.49  B000006045       []              []
# 912     $11.49  B000006045       []              []
# ...        ...         ...      ...             ...
# 139046     NaN  B00KILDVEI      NaN             NaN
# 139047     NaN  B00KILDVEI      NaN             NaN
# 139048     NaN  B00KILDVEI      NaN             NaN
# 139049     NaN  B00KILDVEI      NaN             NaN
# 139050     NaN  B00KILDVEI      NaN             NaN
#
#                                                   details      reviewerID  \
# 908     {'Audio CD': '(May 12, 1998)', 'Original Relea...  A3BFJFJRXMWXAX
# 909     {'Audio CD': '(May 12, 1998)', 'Original Relea...  A34YDWC3VGB366
# 910     {'Audio CD': '(May 12, 1998)', 'Original Relea...  A3EHRBLC0FWCIY
# 911     {'Audio CD': '(May 12, 1998)', 'Original Relea...  A32KPDQ2JT3ANM
# 912     {'Audio CD': '(May 12, 1998)', 'Original Relea...  A3LPD7NTGFH7V4
# ...                                                   ...             ...
# 139046                                                NaN  A1PQ1PESSO8CMO
# 139047                                                NaN  A120RH58WVY4W6
# 139048                                                NaN  A19VJ2IQLO50G0
# 139049                                                NaN   AUDSM2CTLLW1Q
# 139050                                                NaN  A1GN8UJIZLCA59
#
#                                     reviewerName  helpful  \
# 908                              Andy Williamson   [0, 0]
# 909                                 Arevee "Mel"   [0, 0]
# 910     Avernus "Ogne Speranza, Voi Ch'intrante"   [1, 1]
# 911                                       Booker   [1, 5]
# 912                                   bowery boy  [6, 26]
# ...                                          ...      ...
# 139046                          Ginger Christmas   [0, 0]
# 139047               Kelly Dunwell "avid reader"   [0, 0]
# 139048                                   melinda   [0, 1]
# 139049                        Patrick L. Randall   [0, 0]
# 139050                                  P Magnum   [1, 2]
#
#                                                reviewText  overall  \
# 908     Lay down on your couch, put on your headphones...      5.0
# 909     The task of finding good new music is a diffic...      4.0
# 910     What could I possibly say in this review that ...      5.0
# 911     Easily this ecclectic group's best album, "Mez...      5.0
# 912     What is up with all the glowing reviews people...      2.0
# ...                                                   ...      ...
# 139046  I like the reggae sound a lot in this song. I ...      4.0
# 139047  I first heard this on Sirius and had to have i...      5.0
# 139048  I absolutely love this song, it downloaded fin...      5.0
# 139049  Reggae, island beats aren't really my cup of t...      3.0
# 139050  Magic! is a Canadian band that incorporates re...      1.0
#
#                                            summary  unixReviewTime  \
# 908     A midnight masterpiece: Best of the 1990's    1.012176e+09
# 909                         Refreshing Alternative    1.027123e+09
# 910                                     Essentual.    1.172794e+09
# 911                   Massive Attack's Finest Hour    1.159315e+09
# 912                               pluhhhhhease!!!!    1.065139e+09
# ...                                            ...             ...
# 139046                                   Cool song    1.403568e+09
# 139047                                  Great Song    1.404864e+09
# 139048                                  Five Stars    1.405210e+09
# 139049                           Well-crafted song    1.404864e+09
# 139050                              Souless Reggae    1.405642e+09
#
#          reviewTime
# 908     01 28, 2002
# 909     07 20, 2002
# 910      03 2, 2007
# 911     09 27, 2006
# 912      10 3, 2003
# ...             ...
# 139046  06 24, 2014
# 139047   07 9, 2014
# 139048  07 13, 2014
# 139049   07 9, 2014
# 139050  07 18, 2014
#
# [64706 rows x 27 columns]

# %%
#mean = 4.22251414088338
#std = 1.0860728858361215

#merging_dig_df['overall'] = np.random.normal(mean, std, len(merging_dig_df))
#plt.hist(merging_dig_df['overall'], bins=1000)

#plt.show()

# %%
sns.displot(merging_dig_df, x="overall", kde=True)
plt.show()

# %%
merging_cd_df = pd.merge(metacd_df, cd_df, on="asin", how="outer")
merging_cd_df = merging_cd_df.dropna(subset=['overall'])
pd.options.display.max_columns = None
merging_cd_df
# Out:
#                          category tech1 description  fit  \
# 0        [CDs & Vinyl, Christian]                []
# 1        [CDs & Vinyl, Christian]                []
# 2        [CDs & Vinyl, Christian]                []
# 3        [CDs & Vinyl, Christian]                []
# 4        [CDs & Vinyl, Christian]                []
# ...                           ...   ...         ...  ...
# 2156151                       NaN   NaN         NaN  NaN
# 2156152                       NaN   NaN         NaN  NaN
# 2156153                       NaN   NaN         NaN  NaN
# 2156154                       NaN   NaN         NaN  NaN
# 2156155                       NaN   NaN         NaN  NaN
#
#                           title  \
# 0        Songs for the Shepherd
# 1        Songs for the Shepherd
# 2        Songs for the Shepherd
# 3        Songs for the Shepherd
# 4        Songs for the Shepherd
# ...                         ...
# 2156151                     NaN
# 2156152                     NaN
# 2156153                     NaN
# 2156154                     NaN
# 2156155                     NaN
#
#                                                   also_buy tech2        brand  \
# 0        [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...        Keith Green
# 1        [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...        Keith Green
# 2        [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...        Keith Green
# 3        [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...        Keith Green
# 4        [B0016CP2GS, B0000075PB, B0000275QQ, B00000I7J...        Keith Green
# ...                                                    ...   ...          ...
# 2156151                                                NaN   NaN          NaN
# 2156152                                                NaN   NaN          NaN
# 2156153                                                NaN   NaN          NaN
# 2156154                                                NaN   NaN          NaN
# 2156155                                                NaN   NaN          NaN
#
#         feature                      rank  \
# 0            []  123,896 in CDs & Vinyl (
# 1            []  123,896 in CDs & Vinyl (
# 2            []  123,896 in CDs & Vinyl (
# 3            []  123,896 in CDs & Vinyl (
# 4            []  123,896 in CDs & Vinyl (
# ...         ...                       ...
# 2156151     NaN                       NaN
# 2156152     NaN                       NaN
# 2156153     NaN                       NaN
# 2156154     NaN                       NaN
# 2156155     NaN                       NaN
#
#                                                  also_view  \
# 0        [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 1        [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 2        [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 3        [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# 4        [B0016CP2GS, B00000I7JO, B00000I9AH, B00P826ZR...
# ...                                                    ...
# 2156151                                                NaN
# 2156152                                                NaN
# 2156153                                                NaN
# 2156154                                                NaN
# 2156155                                                NaN
#
#                                                   main_cat similar_item date  \
# 0        <img src="https://images-na.ssl-images-amazon....
# 1        <img src="https://images-na.ssl-images-amazon....
# 2        <img src="https://images-na.ssl-images-amazon....
# 3        <img src="https://images-na.ssl-images-amazon....
# 4        <img src="https://images-na.ssl-images-amazon....
# ...                                                    ...          ...  ...
# 2156151                                                NaN          NaN  NaN
# 2156152                                                NaN          NaN  NaN
# 2156153                                                NaN          NaN  NaN
# 2156154                                                NaN          NaN  NaN
# 2156155                                                NaN          NaN  NaN
#
#         price        asin imageURL imageURLHighRes details      reviewerID  \
# 0              0001393774       []              []     NaN  A1H1DL4K669VQ9
# 1              0001393774       []              []     NaN  A3V5XBBT7OZG5G
# 2              0001393774       []              []     NaN  A3SNL7UJY7GWBI
# 3              0001393774       []              []     NaN  A3478QRKQDOPQ2
# 4              0001393774       []              []     NaN  A23M5VTSN2C3H1
# ...       ...         ...      ...             ...     ...             ...
# 2156151   NaN  B01FWSNV4Q      NaN             NaN     NaN   A4X3OX396WX8A
# 2156152   NaN  B01FWSNV4Q      NaN             NaN     NaN  A2F48IDX8Z0AAN
# 2156153   NaN  B01FWSNV4Q      NaN             NaN     NaN  A3SA404H7PBCGW
# 2156154   NaN  B01FWSNV4Q      NaN             NaN     NaN  A3BU0AXTB34WQW
# 2156155   NaN  B01FWSNV4Q      NaN             NaN     NaN  A1AKM268EXO1CY
#
#               reviewerName verified  \
# 0          Judith Paladino     True
# 1                   gflady     True
# 2         Lady Leatherneck     True
# 3                    jacki     True
# 4                  Caliope     True
# ...                    ...      ...
# 2156151          BLAIRFACE     True
# 2156152         Verimyrkky     True
# 2156153              Erich    False
# 2156154  Storming Mountain     True
# 2156155      jessica baker     True
#
#                                                 reviewText  overall  \
# 0                                 Love it!!  Great seller!      5.0
# 1        One of my very favourite albums from one of my...      5.0
# 2        THank you Jesus Lord God, that brother Green's...      5.0
# 3        I recall loving his other albums and maybe thi...      5.0
# 4        Keith Green was a pioneer in the field of Chri...      5.0
# ...                                                    ...      ...
# 2156151  Better than any of there other cds.....the voc...      5.0
# 2156152     My husband and I love this band.  Great album!      5.0
# 2156153  Truly amazing album ......this is black metal ...      5.0
# 2156154  Inquisition's last work does not disappoint. A...      5.0
# 2156155  I cant believe no one has reviewed this fantas...      5.0
#
#           reviewTime                                            summary  \
# 0        04 29, 2016                                         Five Stars
# 1        02 23, 2016  One of my very favourite albums from one of my...
# 2        02 11, 2016                                         Five Stars
# 3        11 28, 2015  forgot but I figured on some of these artists ...
# 4        12 16, 2014                and I have loved every album he did
# ...              ...                                                ...
# 2156151   11 5, 2017                                          Jack Glow
# 2156152  09 22, 2017                                        Great Album
# 2156153  11 13, 2016                      Black metal at its very best.
# 2156154  10 26, 2016                                         Five Stars
# 2156155  09 14, 2016                            LET THE BLOODSHED BEGIN
#
#          unixReviewTime                     style vote image
# 0          1.461888e+09                       NaN  NaN   NaN
# 1          1.456186e+09                       NaN  NaN   NaN
# 2          1.455149e+09                       NaN  NaN   NaN
# 3          1.448669e+09                       NaN  NaN   NaN
# 4          1.418688e+09                       NaN  NaN   NaN
# ...                 ...                       ...  ...   ...
# 2156151    1.509840e+09  {'Format:': ' Audio CD'}  NaN   NaN
# 2156152    1.506038e+09  {'Format:': ' Audio CD'}  NaN   NaN
# 2156153    1.478995e+09  {'Format:': ' Audio CD'}    2   NaN
# 2156154    1.477440e+09  {'Format:': ' Audio CD'}  NaN   NaN
# 2156155    1.473811e+09  {'Format:': ' Audio CD'}    9   NaN
#
# [1722761 rows x 30 columns]

# %%
#pie chart showing the percentage of each rating (0-5) in digital music reviews
cd_groupby = merging_dig_df.groupby('overall').count()['asin']
labels = ['1', '2', '3', '4', '5']
explode = (0,0,0,0,0)
colors = ["orange", "blue", "red", "yellow", "green"]
plt.pie(cd_groupby, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", startangle=180)
plt.title('Digital Music Overall Rating (0-5)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#pie chart showing the percentage of each rating (0-5) in CDs & Vinyl reviews
cd_groupby = merging_cd_df.groupby('overall').count()['asin']
labels = ['1', '2', '3', '4', '5']
explode = (0,0,0,0,0)
colors = ["orange", "blue", "red", "yellow", "green"]
plt.pie(cd_groupby, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", startangle=180)
plt.title('CD & Vinyl Overall Rating (0-5)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#calculations for Lower, Upper and Interquartile of occupancy for overall ratings in Digital Music.
#Lower bound and outlier range is determined
dig_rating = merging_dig_df['overall']
dig_quartiles = dig_rating.quantile([0.25,0.5,0.75])
dig_lq = dig_quartiles[0.25]
dig_medq = dig_quartiles[.5]
dig_uq = dig_quartiles[0.75]
dig_iqr = dig_uq - dig_lq
print('Digital Music overall ratings')
print(f'The lower quartile of occupancy is: {dig_lq}')
print(f'The upper quartile of occupancy is: {dig_uq}')
print(f'The interquartile range of occupancy is: {dig_iqr}')
print(f'The median of occupancy is: {dig_medq}')
dig_lowerbound = dig_lq - 1.5*dig_iqr
dig_upperbound = dig_uq + 1.5*dig_iqr
print(f'Lower Bound: {dig_lowerbound}')
print(f'Values below {dig_lowerbound} could be outliers.')
# Out:
# Digital Music overall ratings
# The lower quartile of occupancy is: 3.498640442706588
# The upper quartile of occupancy is: 4.962646162599167
# The interquartile range of occupancy is: 1.4640057198925795
# The median of occupancy is: 4.230031037525002
# Lower Bound: 1.3026318628677185
# Values below 1.3026318628677185 could be outliers.

# %%
#calculations for Lower, Upper and Interquartile of occupancy for overall ratings in CDs & Vinyl.
#Lower bound and outlier range is determined
cd_rating = merging_cd_df['overall']
cd_quartiles = cd_rating.quantile([0.25,0.5,0.75])
cd_lq = cd_quartiles[0.25]
cd_medq = cd_quartiles[.5]
cd_uq = cd_quartiles[0.75]
cd_iqr = cd_uq - cd_lq
print('CD & vinyl overall ratings')
print(f'The lower quartile of occupancy is: {cd_lq}')
print(f'The upper quartile of occupancy is: {cd_uq}')
print(f'The interquartile range of occupancy is: {cd_iqr}')
print(f'The median of occupancy is: {cd_medq}')
cd_lowerbound = cd_lq - 1.5*cd_iqr
cd_upperbound = cd_uq + 1.5*cd_iqr
print(f'Lower Bound: {cd_lowerbound}')
print(f'Values below {cd_lowerbound} could be outliers.')
# Out:
# CD & vinyl overall ratings
# The lower quartile of occupancy is: 4.0
# The upper quartile of occupancy is: 5.0
# The interquartile range of occupancy is: 1.0
# The median of occupancy is: 5.0
# Lower Bound: 2.5
# Values below 2.5 could be outliers.

# %%
#Box plot between CDs & Vinyl and digital music datasets.
#Figure represents findings from Quartile calculations
box_plot = [cd_rating, dig_rating]

fig1, ax1 = plt.subplots()
ax1.set_title('Ratings by Music Product')
ax1.set_xlabel('Music Product')
ax1.set_ylabel('Rating')

ax1.boxplot(box_plot, labels=["CD & Vinyl","Digital Music"])
plt.show()

# %%
#Scatter plot of Popularity (number of reviews given to an album) vs. Avg Rating in the CDs & Vinyl dataset
#Figure shows a very weak negative correlation between the two variables
cd_popularity = merging_cd_df.groupby(["asin"])['asin'].count()
groupby_cd_rating = merging_cd_df.groupby(['asin'])['overall'].mean()
plt.scatter(cd_popularity, groupby_cd_rating, color = "blue")
plt.xlabel("Reviews Count")
plt.ylabel("Rating")
plt.title("Reviews Count vs Avg. Rating")
plt.show()

# %%
#Scatter plot of Popularity (number of reviews given to an album) vs. Avg Rating in the digital music dataset
#Figure shows a very weak negative correlation between the two variables
dig_popularity = merging_dig_df.groupby(["asin"])['asin'].count()
groupby_dig_rating = merging_dig_df.groupby(['asin'])['overall'].mean()
plt.scatter(cd_popularity, groupby_cd_rating, color = "blue")
plt.xlabel("Reviews Count")
plt.ylabel("Rating")
plt.title("Reviews Count vs Avg. Rating")
plt.show()

# %%
print(f"The correlation coefficient between Reviews Count of Album and its Avg. rating is {round(st.pearsonr(cd_popularity, groupby_cd_rating)[0],2)}")
# Out:
# The correlation coefficient between Reviews Count of Album and its Avg. rating is -0.04
