# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import sem

# %%
#EV data files
ev_sales_path = "EV_Sales.csv"
ev_traits_path = "EV_Traits.csv"
global_data_path = "GlobalData.csv"

#Read the EV data files
ev_sales = pd.read_csv(ev_sales_path)
ev_traits = pd.read_csv(ev_traits_path)
global_data = pd.read_csv(global_data_path)

#merging data tabels
merge_df = pd.merge(ev_sales, ev_traits, on = "Make", how = "outer")

#display the data 
merge_df.head()
# Out:
#         Make    Model_x                                               Logo  \
# 0  Chevrolet       Volt  https://www.carlogos.org/logo/Chevrolet-logo-2...
# 1  Chevrolet   Spark EV  https://www.carlogos.org/logo/Chevrolet-logo-2...
# 2  Chevrolet    Bolt EV  https://www.carlogos.org/logo/Chevrolet-logo-2...
# 3     Toyota  Prius PHV  https://www.carlogos.org/logo/Toyota-logo-1989...
# 4     Toyota    Rav4 EV  https://www.carlogos.org/logo/Toyota-logo-1989...
#
#    janv-12  Feb 2012  mars-12  Apr 2012  May 2012  juin-12  juil-12  ...  \
# 0    603.0    1626.0   3915.0    5377.0    7057.0   8817.0  10666.0  ...
# 1      NaN       NaN      NaN       NaN       NaN      NaN      NaN  ...
# 2      NaN       NaN      NaN       NaN       NaN      NaN      NaN  ...
# 3      0.0      21.0    912.0    2566.0    3652.0   4347.0   5035.0  ...
# 4      0.0       NaN      NaN       NaN       NaN      NaN      NaN  ...
#
#    Range_Km  Efficiency_WhKm  FastCharge_KmH  RapidCharge  PowerTrain  \
# ...
